# %%
import os
import sys
import torch
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Project root link karna taaki models import ho sakein
NOTEBOOK_DIR = os.getcwd()
PROJECT_ROOT = os.path.abspath(os.path.join(NOTEBOOK_DIR, ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from models.segmentation.dataset import DeepGlobeDataset
print("✅ Imports aur Path links bilkul ready hain!")
# Out:
# ✅ Imports aur Path links bilkul ready hain!

# %%
# DeepLabV3+ architecture load karna
# Assuming standard segmentation architecture initialized with 7 classes
from torchvision.models.segmentation import deeplabv3_resnet50

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = deeplabv3_resnet50(num_classes=7)
model = model.to(device)
print(f"🤖 Model Architecture successfully loaded on: [{device}]")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to C:\Users\Lenovo/.cache\torch\hub\checkpoints\resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:21<00:00, 4.66MB/s]
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In[3], line 7
#       3 from torchvision.models.segmentation import deeplabv3_resnet50
#       4
#       5 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       6 model = deeplabv3_resnet50(num_classes=7)
# ----> 7 model = model.to(device)
#       8 print(f"🤖 Model Architecture successfully loaded on: [{device}]")
#
# File d:\project data\AI_afforestation\ai_env\Lib\site-packages\torch\nn\modules\module.py:1383, in Module.to(self, *args, **kwargs)
#    1380         else:
#    1381             raise
# -> 1383 return self._apply(convert)
#
# ...
